# %%
import pandas as pd

# %%
data=pd.read_csv(r'used_cars_data.csv')

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data.Mileage.min
# Out:
# <bound method Series.min of 0       26.6 km/kg
# 1       19.67 kmpl
# 2        18.2 kmpl
# 3       20.77 kmpl
# 4        15.2 kmpl
#            ...
# 7248    20.54 kmpl
# 7249    17.21 kmpl
# 7250    23.08 kmpl
# 7251     17.2 kmpl
# 7252     10.0 kmpl
# Name: Mileage, Length: 7253, dtype: object>

# %%
data['Mileage']=data.Mileage.str.split(' ',expand=True)[0]

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data['Mileage']=data['Mileage'].astype('float')

# %%
data.Mileage.mean()
# Out:
# np.float64(18.141580471659083)

# %%
data.Power.str.split('',expand=True)[0]
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 7248
# 7249
# 7250
# 7251
# 7252
# Name: 0, Length: 7253, dtype: object

# %%
data.Power.value_counts()
# Out:
# Power
# 74 bhp       280
# 98.6 bhp     166
# 73.9 bhp     152
# 140 bhp      142
# null bhp     129
#             ...
# 382 bhp        1
# 552 bhp        1
# 560 bhp        1
# 360 bhp        1
# 241.6 bhp      1
# Name: count, Length: 386, dtype: int64

# %%
pd.to_numeric(data['Power'], errors='coerce')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 7248   NaN
# 7249   NaN
# 7250   NaN
# 7251   NaN
# 7252   NaN
# Name: Power, Length: 7253, dtype: float64

# %%
data['Power']=pd.to_numeric(data['Power'], errors='coerce')

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
# ...

# %%
data.Name.str.split(' ',expand=True)[0]
# Out:
# 0              Maruti
# 1             Hyundai
# 2               Honda
# 3              Maruti
# 4                Audi
#             ...
# 7248       Volkswagen
# 7249       Volkswagen
# 7250           Nissan
# 7251       Volkswagen
# 7252    Mercedes-Benz
# Name: 0, Length: 7253, dtype: object

# %%
data
# Out:
#       S.No.           Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0         0         Maruti      Mumbai  2010              72000       CNG
# 1         1        Hyundai        Pune  2015              41000    Diesel
# 2         2          Honda     Chennai  2011              46000    Petrol
# 3         3         Maruti     Chennai  2012              87000    Diesel
# 4         4           Audi  Coimbatore  2013              40670    Diesel
# ...     ...            ...         ...   ...                ...       ...
# 7248   7248     Volkswagen   Hyderabad  2011              89411    Diesel
# 7249   7249     Volkswagen      Mumbai  2015              59000    Petrol
# 7250   7250         Nissan     Kolkata  2012              28000    Diesel
# 7251   7251     Volkswagen        Pune  2013              52262    Petrol
# 7252   7252  Mercedes-Benz       Kochi  2014              72443    Diesel
#
#      Transmission Owner_Type  Mileage   Engine  Power  Seats  New_Price  Price
# ...

# %%
data['Brand']=data.Name.str.split(' ',expand=True)[0]

# %%
data['Brand']
# Out:
# 0              Maruti
# 1             Hyundai
# 2               Honda
# 3              Maruti
# 4                Audi
#             ...
# 7248       Volkswagen
# 7249       Volkswagen
# 7250           Nissan
# 7251       Volkswagen
# 7252    Mercedes-Benz
# Name: Brand, Length: 7253, dtype: object

# %%
data
# Out:
#       S.No.           Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0         0         Maruti      Mumbai  2010              72000       CNG
# 1         1        Hyundai        Pune  2015              41000    Diesel
# 2         2          Honda     Chennai  2011              46000    Petrol
# 3         3         Maruti     Chennai  2012              87000    Diesel
# 4         4           Audi  Coimbatore  2013              40670    Diesel
# ...     ...            ...         ...   ...                ...       ...
# 7248   7248     Volkswagen   Hyderabad  2011              89411    Diesel
# 7249   7249     Volkswagen      Mumbai  2015              59000    Petrol
# 7250   7250         Nissan     Kolkata  2012              28000    Diesel
# 7251   7251     Volkswagen        Pune  2013              52262    Petrol
# 7252   7252  Mercedes-Benz       Kochi  2014              72443    Diesel
#
#      Transmission Owner_Type  Mileage   Engine  Power  Seats  New_Price  \
# ...

# %%
data.drop('Name',axis=1, inplace=True)

# %%
data.drop('S.No.',axis=1, inplace=True)

# %%
data
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 7248   Hyderabad  2011              89411    Diesel       Manual      First
# 7249      Mumbai  2015              59000    Petrol    Automatic      First
# 7250     Kolkata  2012              28000    Diesel       Manual      First
# 7251        Pune  2013              52262    Petrol    Automatic      Third
# 7252       Kochi  2014              72443    Diesel    Automatic      First
#
# ...

# %% [markdown]
# # Rename the colums

# %%
data.rename(columns={'Kilometers_Driven': 'run', 'Fuel_Type': 'Fuel', 'Transmission': 'trans'}, inplace=True)

# %%
data.shape
# Out:
# (7253, 13)

# %%
data
# Out:
#         Location  Year    run    Fuel       tans Owner_Type  Mileage   Engine  \
# 0         Mumbai  2010  72000     CNG     Manual      First    26.60   998 CC
# 1           Pune  2015  41000  Diesel     Manual      First    19.67  1582 CC
# 2        Chennai  2011  46000  Petrol     Manual      First    18.20  1199 CC
# 3        Chennai  2012  87000  Diesel     Manual      First    20.77  1248 CC
# 4     Coimbatore  2013  40670  Diesel  Automatic     Second    15.20  1968 CC
# ...          ...   ...    ...     ...        ...        ...      ...      ...
# 7248   Hyderabad  2011  89411  Diesel     Manual      First    20.54  1598 CC
# 7249      Mumbai  2015  59000  Petrol  Automatic      First    17.21  1197 CC
# 7250     Kolkata  2012  28000  Diesel     Manual      First    23.08  1461 CC
# 7251        Pune  2013  52262  Petrol  Automatic      Third    17.20  1197 CC
# 7252       Kochi  2014  72443  Diesel  Automatic      First    10.00  2148 CC
#
# ...

# %%
data.columns
# Out:
# Index(['Location', 'Year', 'run', 'Fuel', 'tans', 'Owner_Type', 'Mileage',
#        'Engine', 'Power', 'Seats', 'New_Price', 'Price', 'Brand'],
#       dtype='object')

# %%
data.head(1)
# Out:
#   Location  Year    run Fuel    tans Owner_Type  Mileage  Engine  Power  \
# 0   Mumbai  2010  72000  CNG  Manual      First     26.6  998 CC    NaN
#
#    Seats New_Price  Price   Brand
# 0    5.0       NaN   1.75  Maruti

# %% [markdown]
# # handling the mmissing values

# %%
data.isna().sum()
# Out:
# Location         0
# Year             0
# run              0
# Fuel             0
# tans             0
# Owner_Type       0
# Mileage          2
# Engine          46
# Power         7253
# Seats           53
# New_Price     6247
# Price         1234
# Brand            0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Location         0
# Year             0
# run              0
# Fuel             0
# tans             0
# Owner_Type       0
# Mileage          2
# Engine          46
# Power         7253
# Seats           53
# New_Price     6247
# Price         1234
# Brand            0
# dtype: int64

# %%
data.drop(['New_Price','Price'],axis=1,inplace=True)

# %%
data
# Out:
#         Location  Year    run    Fuel       tans Owner_Type  Mileage   Engine  \
# 0         Mumbai  2010  72000     CNG     Manual      First    26.60   998 CC
# 1           Pune  2015  41000  Diesel     Manual      First    19.67  1582 CC
# 2        Chennai  2011  46000  Petrol     Manual      First    18.20  1199 CC
# 3        Chennai  2012  87000  Diesel     Manual      First    20.77  1248 CC
# 4     Coimbatore  2013  40670  Diesel  Automatic     Second    15.20  1968 CC
# ...          ...   ...    ...     ...        ...        ...      ...      ...
# 7248   Hyderabad  2011  89411  Diesel     Manual      First    20.54  1598 CC
# 7249      Mumbai  2015  59000  Petrol  Automatic      First    17.21  1197 CC
# 7250     Kolkata  2012  28000  Diesel     Manual      First    23.08  1461 CC
# 7251        Pune  2013  52262  Petrol  Automatic      Third    17.20  1197 CC
# 7252       Kochi  2014  72443  Diesel  Automatic      First    10.00  2148 CC
#
# ...

# %%
data.isnull().sum()
# Out:
# Location         0
# Year             0
# run              0
# Fuel             0
# tans             0
# Owner_Type       0
# Mileage          2
# Engine          46
# Power         7253
# Seats           53
# Brand            0
# dtype: int64

# %%
data.dropna(subset='Mileage',inplace=True)

# %%
data.isna().sum()
# Out:
# Location         0
# Year             0
# run              0
# Fuel             0
# tans             0
# Owner_Type       0
# Mileage          0
# Engine          46
# Power         7251
# Seats           53
# Brand            0
# dtype: int64

# %%
x=data.Engine.mean

# %%
x
# Out:
# <bound method Series.mean of 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 7248    1598 CC
# 7249    1197 CC
# 7250    1461 CC
# 7251    1197 CC
# 7252    2148 CC
# Name: Engine, Length: 7251, dtype: object>

# %%
data.Engine.fillna(x)
# Out:
# 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 7248    1598 CC
# 7249    1197 CC
# 7250    1461 CC
# 7251    1197 CC
# 7252    2148 CC
# Name: Engine, Length: 7251, dtype: object

# %%
data.isna().sum()
# Out:
# Location         0
# Year             0
# run              0
# Fuel             0
# tans             0
# Owner_Type       0
# Mileage          0
# Engine          46
# Power         7251
# Seats           53
# Brand            0
# dtype: int64

# %%
data['Power'] = data['Power'].fillna(method='bfill')  # Use backward fill
# Out:
# C:\Users\Aayush\AppData\Local\Temp\ipykernel_13628\3020398607.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Power'] = data['Power'].fillna(method='bfill')  # Use backward fill

# %%
data.to_csv('cars_eda_clean.csv',index=False)

# %%
data
# Out:
#         Location  Year    run    Fuel       tans Owner_Type  Mileage   Engine  \
# 0         Mumbai  2010  72000     CNG     Manual      First    26.60   998 CC
# 1           Pune  2015  41000  Diesel     Manual      First    19.67  1582 CC
# 2        Chennai  2011  46000  Petrol     Manual      First    18.20  1199 CC
# 3        Chennai  2012  87000  Diesel     Manual      First    20.77  1248 CC
# 4     Coimbatore  2013  40670  Diesel  Automatic     Second    15.20  1968 CC
# ...          ...   ...    ...     ...        ...        ...      ...      ...
# 7248   Hyderabad  2011  89411  Diesel     Manual      First    20.54  1598 CC
# 7249      Mumbai  2015  59000  Petrol  Automatic      First    17.21  1197 CC
# 7250     Kolkata  2012  28000  Diesel     Manual      First    23.08  1461 CC
# 7251        Pune  2013  52262  Petrol  Automatic      Third    17.20  1197 CC
# 7252       Kochi  2014  72443  Diesel  Automatic      First    10.00  2148 CC
#
# ...

# %%
data=pd.read_csv(r'car_clean.csv')

# %%
data
# Out:
#               brand    model    Location  Year    run    fuel      trans  \
# 0            Maruti    Wagon      Mumbai  2010  72000     CNG     Manual
# 1           Hyundai    Creta        Pune  2015  41000  Diesel     Manual
# 2             Honda     Jazz     Chennai  2011  46000  Petrol     Manual
# 3            Maruti   Ertiga     Chennai  2012  87000  Diesel     Manual
# 4              Audi       A4  Coimbatore  2013  40670  Diesel  Automatic
# ...             ...      ...         ...   ...    ...     ...        ...
# 7246     Volkswagen    Vento   Hyderabad  2011  89411  Diesel     Manual
# 7247     Volkswagen     Polo      Mumbai  2015  59000  Petrol  Automatic
# 7248         Nissan    Micra     Kolkata  2012  28000  Diesel     Manual
# 7249     Volkswagen     Polo        Pune  2013  52262  Petrol  Automatic
# 7250  Mercedes-Benz  E-Class       Kochi  2014  72443  Diesel  Automatic
#
#        owner  Mileage  Engine   Power  Seats
# 0      First    26.60   998.0   58.16      5
# ...

# %%
data.brand.unique()
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Smart', 'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley',
#        'Lamborghini', 'Hindustan', 'OpelCorsa'], dtype=object)

# %%
data.brand.value_counts()
# Out:
# brand
# Maruti           1444
# Hyundai          1340
# Honda             743
# Toyota            506
# Mercedes-Benz     380
# Volkswagen        374
# Ford              351
# Mahindra          330
# BMW               312
# Audi              285
# Tata              228
# Skoda             202
# Renault           170
# Chevrolet         151
# Nissan            117
# Land               67
# Jaguar             48
# Fiat               38
# Mitsubishi         36
# Mini               31
# Volvo              28
# Jeep               19
# Porsche            19
# Datsun             17
# Force               3
# ISUZU               3
# Isuzu               2
# Bentley             2
# Smart               1
# Ambassador          1
# Lamborghini         1
# Hindustan           1
# OpelCorsa           1
# Name: count, dtype: int64

# %%
data.model.value_counts().head()
# Out:
# model
# Swift     418
# City      318
# i20       303
# Innova    203
# Verna     200
# Name: count, dtype: int64

# %%
data.model.value_counts(ascending=True).head()
# Out:
# model
# Countryman    1
# Abarth        1
# Mustang       1
# Fusion        1
# CLS-Class     1
# Name: count, dtype: int64

# %%
con1=data['fuel']=='Petrol'
con2=data['trans']=='Automatic'

# %%
data
# Out:
#               brand    model    Location  Year    run    fuel      trans  \
# 0            Maruti    Wagon      Mumbai  2010  72000     CNG     Manual
# 1           Hyundai    Creta        Pune  2015  41000  Diesel     Manual
# 2             Honda     Jazz     Chennai  2011  46000  Petrol     Manual
# 3            Maruti   Ertiga     Chennai  2012  87000  Diesel     Manual
# 4              Audi       A4  Coimbatore  2013  40670  Diesel  Automatic
# ...             ...      ...         ...   ...    ...     ...        ...
# 7246     Volkswagen    Vento   Hyderabad  2011  89411  Diesel     Manual
# 7247     Volkswagen     Polo      Mumbai  2015  59000  Petrol  Automatic
# 7248         Nissan    Micra     Kolkata  2012  28000  Diesel     Manual
# 7249     Volkswagen     Polo        Pune  2013  52262  Petrol  Automatic
# 7250  Mercedes-Benz  E-Class       Kochi  2014  72443  Diesel  Automatic
#
#        owner  Mileage  Engine   Power  Seats
# 0      First    26.60   998.0   58.16      5
# ...

# %%
data[con1&con2].shape
# Out:
# (730, 12)

# %%
data[data['Mileage']==0]
# Out:
#               brand    model    Location  Year    run    fuel      trans  \
# 14             Land    Rover        Pune  2012  85000  Diesel  Automatic
# 67    Mercedes-Benz  C-Class  Coimbatore  2019  15369  Diesel  Automatic
# 79          Hyundai   Santro   Hyderabad  2005  87591  Petrol     Manual
# 194           Honda     City   Ahmedabad  2007  60006  Petrol     Manual
# 229            Ford     Figo   Bangalore  2015  70436  Diesel     Manual
# ...             ...      ...         ...   ...    ...     ...        ...
# 6631       Mahindra      TUV     Kolkata  2016  27000  Diesel     Manual
# 6695        Hyundai   Santro      Jaipur  2007  85000  Petrol     Manual
# 6855           Land    Rover      Mumbai  2011  87000  Diesel  Automatic
# 6955          Honda     Jazz       Kochi  2019  11574  Petrol     Manual
# 7224        Hyundai   Santro   Ahmedabad  2014  41000  Petrol     Manual
#
#        owner  Mileage       Engine   Power  Seats
# ...

# %%
data[data['Mileage']!=0]
# Out:
#               brand    model    Location  Year    run    fuel      trans  \
# 0            Maruti    Wagon      Mumbai  2010  72000     CNG     Manual
# 1           Hyundai    Creta        Pune  2015  41000  Diesel     Manual
# 2             Honda     Jazz     Chennai  2011  46000  Petrol     Manual
# 3            Maruti   Ertiga     Chennai  2012  87000  Diesel     Manual
# 4              Audi       A4  Coimbatore  2013  40670  Diesel  Automatic
# ...             ...      ...         ...   ...    ...     ...        ...
# 7246     Volkswagen    Vento   Hyderabad  2011  89411  Diesel     Manual
# 7247     Volkswagen     Polo      Mumbai  2015  59000  Petrol  Automatic
# 7248         Nissan    Micra     Kolkata  2012  28000  Diesel     Manual
# 7249     Volkswagen     Polo        Pune  2013  52262  Petrol  Automatic
# 7250  Mercedes-Benz  E-Class       Kochi  2014  72443  Diesel  Automatic
#
#        owner  Mileage  Engine   Power  Seats
# 0      First    26.60   998.0   58.16      5
# ...

# %%
data=data[data['Mileage']!=0]

# %%
data
# Out:
#               brand    model    Location  Year    run    fuel      trans  \
# 0            Maruti    Wagon      Mumbai  2010  72000     CNG     Manual
# 1           Hyundai    Creta        Pune  2015  41000  Diesel     Manual
# 2             Honda     Jazz     Chennai  2011  46000  Petrol     Manual
# 3            Maruti   Ertiga     Chennai  2012  87000  Diesel     Manual
# 4              Audi       A4  Coimbatore  2013  40670  Diesel  Automatic
# ...             ...      ...         ...   ...    ...     ...        ...
# 7246     Volkswagen    Vento   Hyderabad  2011  89411  Diesel     Manual
# 7247     Volkswagen     Polo      Mumbai  2015  59000  Petrol  Automatic
# 7248         Nissan    Micra     Kolkata  2012  28000  Diesel     Manual
# 7249     Volkswagen     Polo        Pune  2013  52262  Petrol  Automatic
# 7250  Mercedes-Benz  E-Class       Kochi  2014  72443  Diesel  Automatic
#
#        owner  Mileage  Engine   Power  Seats
# 0      First    26.60   998.0   58.16      5
# ...

# %%
data.Mileage.min
# Out:
# <bound method Series.min of 0       26.60
# 1       19.67
# 2       18.20
# 3       20.77
# 4       15.20
#         ...
# 7246    20.54
# 7247    17.21
# 7248    23.08
# 7249    17.20
# 7250    10.00
# Name: Mileage, Length: 7170, dtype: float64>

# %%
data['Mileage'].min()
# Out:
# np.float64(6.4)

# %%
data['Mileage'].max()
# Out:
# np.float64(33.54)
