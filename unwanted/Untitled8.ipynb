# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# %%
data=pd.read_csv(r'updated_pollution_dataset.csv')

# %%
data
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                               6.3                 319    Moderate
# 1                               6.0                 611    Moderate
# ...

# %%
pca=PCA(n_components=2)

# %%
data = data.drop('Air Quality', axis=1)

# %%
data
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density
# 0                               6.3                 319
# 1                               6.0                 611
# 2                               5.2                 619
# ...

# %%
pca=PCA(n_components=2)

# %%
pca_df=pca.fit_transform(data)

# %%
data
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density
# 0                               6.3                 319
# 1                               6.0                 611
# 2                               5.2                 619
# ...

# %%
plt.title("Data before scaling")
sns.scatterplot(data=data,x='pca1',y='pca2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 plt.title("Data before scaling")
# ----> 2 sns.scatterplot(data=data,x='pca1',y='pca2')
#
# File E:\datascience\venv\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
from sklearn.preprocessing import StandardScalar
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.preprocessing import StandardScalar
#
# ImportError: cannot import name 'StandardScalar' from 'sklearn.preprocessing' (E:\datascience\venv\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
df_scaled=scalar.fit_transform(df)
df_scale=pd.DataFrame(df_scaled,colums=[df
# Out:
#   Cell In[22], line 2
#     df_scale=pd.DataFrame(df_scaled,colums=[df
#                                               ^
# _IncompleteInputError: incomplete input

# %%
df_scaled[

# %%
hiblije.nhuhuhoo

# %%
iisjiofh

# %%
dictonart(x_yhnihij

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('updated_pollution_dataset.csv')

# %%
data = pd.read_csv('updated_pollution_dataset.csv')
data
# Out:
#       Temperature  Humidity  PM2.5   PM10   NO2   SO2    CO  \
# 0            29.8      59.1    5.2   17.9  18.9   9.2  1.72
# 1            28.3      75.6    2.3   12.2  30.8   9.7  1.64
# 2            23.1      74.7   26.7   33.8  24.4  12.6  1.63
# 3            27.1      39.1    6.1    6.3  13.5   5.3  1.15
# 4            26.5      70.7    6.9   16.0  21.9   5.6  1.01
# ...           ...       ...    ...    ...   ...   ...   ...
# 4995         40.6      74.1  116.0  126.7  45.5  25.7  2.11
# 4996         28.1      96.9    6.9   25.0  25.3  10.8  1.54
# 4997         25.9      78.2   14.2   22.1  34.8   7.8  1.63
# 4998         25.3      44.4   21.4   29.0  23.7   5.7  0.89
# 4999         24.1      77.9   81.7   94.3  23.2  10.5  1.38
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                               6.3                 319    Moderate
# 1                               6.0                 611    Moderate
# ...

# %%
shuffled_data = data.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
shuffled_data
# Out:
#       Temperature  Humidity  PM2.5  PM10   NO2   SO2    CO  \
# 0            31.3      73.4   72.8  88.8  54.1  17.1  2.54
# 1            24.0      68.8    0.8   8.6  20.9   2.4  1.16
# 2            25.4      78.6    4.1   6.7  21.3   9.1  1.40
# 3            30.7     102.0    7.9  26.1  41.6  26.1  2.31
# 4            26.5      54.1   12.3  15.3  20.3   5.3  0.99
# ...           ...       ...    ...   ...   ...   ...   ...
# 4995         30.0      59.7   59.3  68.8  22.1   7.4  1.39
# 4996         27.7      54.0   17.6  23.2  24.6  11.1  1.27
# 4997         24.2      67.6   19.4  35.1  24.2   9.6  1.91
# 4998         21.4      76.4   15.3  22.1  12.4   3.4  0.96
# 4999         34.4     103.1   29.2  42.2  54.4  23.6  3.37
#
#       Proximity_to_Industrial_Areas  Population_Density Air Quality
# 0                               2.6                 755   Hazardous
# 1                              10.5                 235        Good
# ...
